# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import math

density = 1000

# Modified 22 March
def generate_gaussian():
    mu = np.random.uniform(low=5,high=200)
    variance = 20
    sigma = math.sqrt(variance)
    x = np.linspace(mu - 3*sigma, mu + 3*sigma, 25)
    y = stats.norm.pdf(x, mu, sigma) * np.random.uniform(low=1, high=8)
    y = y*500

    pref_x = np.array(range(density))
    new_y = np.interp(pref_x,x,y)

    new_y += np.random.uniform(low=0,high=20,size=(density,))

    return (pref_x,new_y)

# def generate_gaussian():
#     mu = np.random.uniform(low=5,high=30)
#     variance = 20
#     sigma = math.sqrt(variance)
#     x = np.linspace(mu - 3*sigma, mu + 3*sigma, 25)
#     y = stats.norm.pdf(x, mu, sigma) * np.random.uniform(low=1, high=8)


#     pref_x = np.array(range(density))
#     new_y = np.interp(pref_x,x,y)

#     new_y += np.random.uniform(low=0,high=0.1,size=(density,))

#     return (pref_x,new_y)



def f(x,a,tau):
    return a * np.exp(-x/tau)


def generate_decay_curve(amin,amax,taumin,taumax):
    a = np.random.uniform(low=amin,high=amax)
    tau = np.random.uniform(low=taumin,high=taumax)
    x = np.array(range(density))
    y = f(x,a,tau)

    return (y,a,tau)
    

def generate_dataset():
    (x,y) = generate_gaussian()
    (dec_y,a,t) = generate_decay_curve()
    z = np.convolve(y,dec_y)[:density]
    # z += np.random.uniform(0,0.2)
    z = z +  np.random.uniform(low=-z/6,high=z/6, size=density)


    input = np.concatenate((z,y))

    t = t/50
    output = (a,t)

    return (input,output)

# %%
def generate_dataset_two():
    (x,y) = generate_gaussian()
    
    (dec_y,a,t) = generate_decay_curve(amin=0.1,amax=1,taumin=0.1,taumax=15)
    (dec_y_2,a2,t2) = generate_decay_curve(amin=0.1,amax=1,taumin=15,taumax=100)

    new_dec = dec_y + dec_y_2

    t = t/15
    t2 = (t2 - 15)/85

    z = np.convolve(y,new_dec)[:density]
    z = z +  np.random.uniform(low=-z/6,high=z/6, size=density)

    input = np.concatenate((z,y))
    output = np.array([a,t,a2,t2,0,0])
    output = output.reshape(6)

    return (input,output)

# %%
""
x_list = []
y_list = []
for i in range(100000):
  
    (x,y) = generate_dataset_two()
  
    x_list.append(x)
    y_list.append(y)

# %%
import matplotlib.pyplot as plt

x = np.array(range(density))
plt.plot(x,x_list[0][:density])
plt.plot(x,x_list[0][density:])
plt.xlabel("Time (ns/100)")
plt.ylabel("Photon counts (a.u)")
plt.title("Plot of photon count against time")
a = y_list[0][0]
tau = y_list[0][1]

# plt.plot(x,f(x,a,tau))
plt.show()

# %%
import tensorflow as tf

x_list = np.array(x_list)
y_list = np.array(y_list)

x_list = tf.keras.utils.normalize(x_list)

print(x_list.shape)
print(y_list.shape)



from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_list, y_list, test_size=0.10, random_state=40)
# Out:
# (100000, 2000)
# (100000, 6)

# %%
import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import layers
import tensorflow as tf


model = Sequential()
model.add(Dense(200, activation='relu', input_dim=density*2))
model.add(Dense(200, activation='relu'))
model.add(Dense(200, activation='relu'))
model.add(Dense(200, activation='relu'))
model.add(Dense(200, activation='relu'))
model.add(Dense(200, activation='relu'))
model.add(Dense(200, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(Dense(6, activation='relu'))

# %%
model.compile(optimizer= tf.keras.optimizers.Adam(learning_rate=1e-5), loss='mean_squared_error', metrics=['accuracy'])
model.fit(X_train, y_train, batch_size=128, epochs=50, validation_split=0.2)
# model.summary()
# Out:
# Epoch 1/50
# 563/563 [==============================] - 13s 22ms/step - loss: 0.1029 - accuracy: 0.2485 - val_loss: 0.0493 - val_accuracy: 0.2661
# Epoch 2/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0560 - accuracy: 0.2652 - val_loss: 0.0433 - val_accuracy: 0.3528
# Epoch 3/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0489 - accuracy: 0.3058 - val_loss: 0.0388 - val_accuracy: 0.3852
# Epoch 4/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0452 - accuracy: 0.3380 - val_loss: 0.0363 - val_accuracy: 0.3963
# Epoch 5/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0427 - accuracy: 0.3629 - val_loss: 0.0351 - val_accuracy: 0.4059
# Epoch 6/50
# 563/563 [==============================] - 10s 17ms/step - loss: 0.0410 - accuracy: 0.3833 - val_loss: 0.0334 - val_accuracy: 0.4299
# Epoch 7/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0390 - accuracy: 0.4012 - val_loss: 0.0317 - val_accuracy: 0.4564
# Epoch 8/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0372 - accuracy: 0.4218 - val_loss: 0.0302 - val_accuracy: 0.4684
# Epoch 9/50
# 563/563 [==============================] - 10s 17ms/step - loss: 0.0359 - accuracy: 0.4347 - val_loss: 0.0293 - val_accuracy: 0.4750
# Epoch 10/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0350 - accuracy: 0.4438 - val_loss: 0.0289 - val_accuracy: 0.4735
# Epoch 11/50
# 563/563 [==============================] - 10s 17ms/step - loss: 0.0342 - accuracy: 0.4476 - val_loss: 0.0287 - val_accuracy: 0.4687
# Epoch 12/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0337 - accuracy: 0.4501 - val_loss: 0.0280 - val_accuracy: 0.4848
# Epoch 13/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0333 - accuracy: 0.4528 - val_loss: 0.0277 - val_accuracy: 0.4837
# Epoch 14/50
# 563/563 [==============================] - 10s 17ms/step - loss: 0.0329 - accuracy: 0.4583 - val_loss: 0.0276 - val_accuracy: 0.4871
# Epoch 15/50
# 563/563 [==============================] - 10s 17ms/step - loss: 0.0326 - accuracy: 0.4614 - val_loss: 0.0274 - val_accuracy: 0.4874
# Epoch 16/50
# 563/563 [==============================] - 10s 17ms/step - loss: 0.0322 - accuracy: 0.4610 - val_loss: 0.0271 - val_accuracy: 0.4909
# Epoch 17/50
# 563/563 [==============================] - 10s 17ms/step - loss: 0.0319 - accuracy: 0.4647 - val_loss: 0.0271 - val_accuracy: 0.4951
# Epoch 18/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0316 - accuracy: 0.4660 - val_loss: 0.0269 - val_accuracy: 0.4942
# Epoch 19/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0314 - accuracy: 0.4691 - val_loss: 0.0268 - val_accuracy: 0.4948
# Epoch 20/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0311 - accuracy: 0.4712 - val_loss: 0.0270 - val_accuracy: 0.4901
# Epoch 21/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0310 - accuracy: 0.4694 - val_loss: 0.0267 - val_accuracy: 0.4918
# Epoch 22/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0307 - accuracy: 0.4713 - val_loss: 0.0265 - val_accuracy: 0.4965
# Epoch 23/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0305 - accuracy: 0.4743 - val_loss: 0.0265 - val_accuracy: 0.4924
# Epoch 24/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0304 - accuracy: 0.4739 - val_loss: 0.0263 - val_accuracy: 0.4947
# Epoch 25/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0301 - accuracy: 0.4771 - val_loss: 0.0262 - val_accuracy: 0.4962
# Epoch 26/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0300 - accuracy: 0.4773 - val_loss: 0.0260 - val_accuracy: 0.4955
# Epoch 27/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0298 - accuracy: 0.4792 - val_loss: 0.0258 - val_accuracy: 0.4988
# Epoch 28/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0296 - accuracy: 0.4799 - val_loss: 0.0259 - val_accuracy: 0.5018
# Epoch 29/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0295 - accuracy: 0.4810 - val_loss: 0.0257 - val_accuracy: 0.4971
# Epoch 30/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0293 - accuracy: 0.4824 - val_loss: 0.0257 - val_accuracy: 0.4998
# Epoch 31/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0291 - accuracy: 0.4838 - val_loss: 0.0255 - val_accuracy: 0.4970
# Epoch 32/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0289 - accuracy: 0.4850 - val_loss: 0.0253 - val_accuracy: 0.5042
# Epoch 33/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0288 - accuracy: 0.4869 - val_loss: 0.0252 - val_accuracy: 0.5003
# Epoch 34/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0285 - accuracy: 0.4885 - val_loss: 0.0251 - val_accuracy: 0.5073
# Epoch 35/50
# 563/563 [==============================] - 10s 17ms/step - loss: 0.0283 - accuracy: 0.4890 - val_loss: 0.0248 - val_accuracy: 0.5102
# Epoch 36/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0281 - accuracy: 0.4895 - val_loss: 0.0247 - val_accuracy: 0.5129
# Epoch 37/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0278 - accuracy: 0.4952 - val_loss: 0.0243 - val_accuracy: 0.5088
# Epoch 38/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0275 - accuracy: 0.4964 - val_loss: 0.0241 - val_accuracy: 0.5145
# Epoch 39/50
# 563/563 [==============================] - 10s 17ms/step - loss: 0.0272 - accuracy: 0.4990 - val_loss: 0.0239 - val_accuracy: 0.5215
# Epoch 40/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0268 - accuracy: 0.5033 - val_loss: 0.0234 - val_accuracy: 0.5226
# Epoch 41/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0265 - accuracy: 0.5061 - val_loss: 0.0232 - val_accuracy: 0.5197
# Epoch 42/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0261 - accuracy: 0.5105 - val_loss: 0.0229 - val_accuracy: 0.5322
# Epoch 43/50
# 563/563 [==============================] - 10s 17ms/step - loss: 0.0258 - accuracy: 0.5122 - val_loss: 0.0223 - val_accuracy: 0.5342
# Epoch 44/50
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0254 - accuracy: 0.5156 - val_loss: 0.0221 - val_accuracy: 0.5304
# Epoch 45/50
# 563/563 [==============================] - 10s 17ms/step - loss: 0.0252 - accuracy: 0.5192 - val_loss: 0.0218 - val_accuracy: 0.5424
# Epoch 46/50
# 563/563 [==============================] - 10s 17ms/step - loss: 0.0248 - accuracy: 0.5225 - val_loss: 0.0218 - val_accuracy: 0.5405
# Epoch 47/50
# 563/563 [==============================] - 10s 17ms/step - loss: 0.0246 - accuracy: 0.5242 - val_loss: 0.0213 - val_accuracy: 0.5449
# Epoch 48/50
# 563/563 [==============================] - 10s 17ms/step - loss: 0.0244 - accuracy: 0.5268 - val_loss: 0.0213 - val_accuracy: 0.5452
# Epoch 49/50
# 563/563 [==============================] - 10s 17ms/step - loss: 0.0242 - accuracy: 0.5302 - val_loss: 0.0210 - val_accuracy: 0.5435
# Epoch 50/50
# 563/563 [==============================] - 10s 17ms/step - loss: 0.0240 - accuracy: 0.5319 - val_loss: 0.0210 - val_accuracy: 0.5463

# %%
model.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 7.1347e-04 - accuracy: 0.9581
# [0.0007134663756005466, 0.9581000208854675]

# %%
m_list = []
n_list = []
for i in range(100):
  (m,n) = generate_dataset_two()
  m_list.append(m)
  n_list.append(n)


m = np.array(m_list)
m = tf.keras.utils.normalize(m)
n = np.array(n_list)

# print(n_list)

# %%
pred_n = model.predict(m)

# %%
pred_n = np.array(pred_n)

# %%
n_list_ = np.array(n_list).T
pred_n_ = pred_n.T

n_list_0 = n_list_[1] * 15
pred_n_0 = pred_n_[1] * 15

# n_list_1 = n_list_[3] * 85 + 15
# pred_n_1 = pred_n_[3] * 85 + 15


# n_list_2 = n_list_[0]
# pred_n_2 = pred_n_[0]

# n_list_4 = n_list_[2]
# pred_n_4 = pred_n_[2]


x = np.array(range(100))/100*15





# plt.scatter(n_list_0,pred_n_0,label="lifetime_1")
plt.scatter(n_list_0,pred_n_0,label="lifetime_1")
# plt.scatter(n_list_1,pred_n_1,label="lifetime_2")
plt.plot(x,x,c='g')
plt.legend()
plt.xlabel("Generated lifetime value (ns)")
plt.ylabel("Predicted lifetime value (ns)")
plt.title("A plot of 50 points of predicted lifetime against generated\n lifetime for a double exponential decay model")
# # plt.show()
# Out:
# Text(0.5, 1.0, 'A plot of 50 points of predicted lifetime against generated\n lifetime for a double exponential decay model')

# %%
(m,n) = generate_dataset_two()

m_norm = tf.keras.utils.normalize(m)

m_norm = np.array(m_norm)

pred_n = model.predict(m_norm)

print(pred_n)

x = np.array(range(1000))
a = float(pred_n[0][0])
tau = float(pred_n[0][1])*15
a2 = float(pred_n[0][2])
tau2 = float(pred_n[0][3]) * 85 + 15
irf = m[density:]
y = np.convolve(irf, f(x,a,tau) + f(x,a2,tau2))[:density]

plt.plot(x,np.log10(irf),label="Instrument Response Function")
plt.plot(x,np.log10(m[:density]),label="Generated Impulse Response Function")
plt.plot(x,np.log10(y),label="Predicted Impulse Response Function")
plt.legend()
plt.xlabel("Time (ns/100)")
plt.ylabel("Photon count in log10 scale (a.u)")
plt.title("Plot of photon count against time in log10 scale \n for a1= {}, a2= {}, t1={}ns and t2= {} ns".format(round(a,2),round(a2,2), round(tau),round(tau2)))
print(n)

plt.show()
# Out:
# [[0.54592925 0.52344894 0.65689635 0.28071925 0.         0.        ]]
# [0.36956353 0.65359402 0.69887438 0.28421737 0.         0.        ]

# %%
y = np.convolve(irf,f(x,a,tau))[:density]

# print(y)

plt.plot(x,y)
plt.show()

# %%
n_ = 1 - np.absolute(pred_n-n)/ pred_n

print(np.mean(n_,axis=0))


# print(np.mean(n_, axis=0))

# n = np.array(n_list)
# pred_n_ = pred_n

# print(np.mean(n,axis=0))
# print(np.mean(pred_n,axis=0))
# Out:
# [0.63191513 0.5103613  0.8424977  0.85882501        nan        nan]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %%
model.save("mymodel")
# Out:
# INFO:tensorflow:Assets written to: mymodel/assets
